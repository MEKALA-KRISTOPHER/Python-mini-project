# %% [markdown]
# <a href="https://colab.research.google.com/github/MEKALA-KRISTOPHER/Python-mini-project/blob/main/Random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1 = []
a2 = []
a3 = []
a4 = []
a5 = []

# %%
for _ in range (1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
df = {
     'grade' : a1,
     'weight': a2,
     'friends':a3,
     'cousins': a4,
     'projects':a5
}

# %%
pip install pandas

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       94      69       17       10        53
# 1       88      70       11        5        66
# 2       25      66       15       10        36
# 3       75      62       19        7        80
# 4       70      66       19        7        48
# ..     ...     ...      ...      ...       ...
# 995     89      53       19        9        49
# 996     43      59       17        5        28
# 997     14      50       20        7        77
# 998     59      55       16        8        37
# 999      9      60       10        8        66
#
# [1000 rows x 5 columns]

# %%
df1.to_csv('feb6testdata.csv')

# %%
df1.describe()
# Out:
#              grade       weight      friends      cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     50.043000    60.073000    14.974000     7.597000    49.457000
# std      28.977005     6.178175     3.218024     1.705726    17.258273
# min       0.000000    50.000000    10.000000     5.000000    20.000000
# 25%      25.000000    55.000000    12.000000     6.000000    34.000000
# 50%      50.000000    60.000000    15.000000     8.000000    49.000000
# 75%      74.000000    65.000000    18.000000     9.000000    64.000000
# max     100.000000    70.000000    20.000000    10.000000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count
# Out:
# <bound method Series.count of 0      94
# 1      88
# 2      25
# 3      75
# 4      70
#        ..
# 995    89
# 996    43
# 997    14
# 998    59
# 999     9
# Name: grade, Length: 1000, dtype: int64>

# %%
freind18 = df1['friends'] > 18

# %%
freind18
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 995     True
# 996    False
# 997     True
# 998    False
# 999    False
# Name: friends, Length: 1000, dtype: bool

# %%
grade98 =df1['grade'] > 98

# %%
df1[grade98]
# Out:
#      grade  weight  friends  cousins  projects
# 194    100      54       19        6        41
# 218     99      50       15        7        39
# 350    100      68       11        7        26
# 357     99      55       18        5        80
# 402    100      57       11       10        40
# 410     99      56       10        9        44
# 520    100      52       18        5        20
# 551     99      53       12        8        55
# 563    100      60       10        8        26
# 568    100      56       12        9        31
# 593    100      58       13        6        61
# 597    100      55       12        8        21
# 697    100      67       19        9        52
# 699    100      56       13        5        54
# 727    100      50       16        5        35
# 820    100      54       12        6        33
# 869    100      53       17        6        62
# 945    100      52       15        9        64
# 988     99      51       11        6        57

# %%
df1[freind18 & grade98]
# Out:
# 194    19
# 697    19
# Name: friends, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
df1.loc[freind18 & grade98, ['grade', 'projects']].plot()
# Out:
# <Axes: >

# %%
matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[freind15 & grade98].plot()
# Out:
# <Axes: >

# %%
df1[freind15 & grade98].plot(x = 'grade',y = 'projects',kind='bar',title='sample graph')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend('Text Data')
plt.show()

# %%
fbf = df1[freind15 & grade98]

# %%
fbf
# Out:
#      grade  weight  friends  cousins  projects
# 194    100      54       19        6        41
# 357     99      55       18        5        80
# 520    100      52       18        5        20
# 697    100      67       19        9        52
# 727    100      50       16        5        35
# 869    100      53       17        6        62

# %%
df1.to_csv('feb6testdata.csv')
